# %%
import warnings
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

warnings.filterwarnings("ignore")
# Out:
# /Users/maidat/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
# def net_operating_income(year, rent_growth_percentage, list_price):
#     # Income
#     rent_growth = rent_growth_percentage
#     purchase_price = list_price
    
#     monthly_rent = purchase_price * (0.8/100)
#     vacancy = 0.05
#     expected_rent = (monthly_rent * (1 - vacancy)) * 12
    
#     income = expected_rent * (1 + rent_growth)**year

#     # Expense
#     property_management = purchase_price * 0.08
#     insurance = (purchase_price / 1000) * 3.5
#     property_tax = purchase_price * 0
#     leasing_fee = purchase_price * 0
#     hoa_fee = purchase_price * 0
#     repair_maint = purchase_price * 0.01
#     utilities = purchase_price * 0.01

#     expense = property_management + insurance + property_tax + \
#         leasing_fee + hoa_fee + repair_maint + utilities

#     # Capital Expenditures (Reverse)
#     capex_r = purchase_price * 0.04

#     # Net Operating Income
#     net_operating_income = income - expense
#     return net_operating_income

# %%
# def monthly_payment(purchase_price, down_payment, current_mortgage_rate, number_of_payment_per_year):
#     starting_loan_amount = purchase_price - (purchase_price * down_payment)
#     loan_interest_rate = current_mortgage_rate
#     number_of_payment_per_year = number_of_payment_per_year
#     monthly_payment = (starting_loan_amount *
#                        (loan_interest_rate / number_of_payment_per_year)) / (
#                            1 -
#                            (1 +
#                             (loan_interest_rate / number_of_payment_per_year)) **
#                            (-(loan_term * number_of_payment_per_year)))
#     return monthly_payment

# def net_operating_income(year, rent_growth_percentage, list_price):
#     # Income
#     rent_growth = rent_growth_percentage
#     purchase_price = list_price
    
#     monthly_rent = purchase_price * (1/100)
#     vacancy = 0.05
#     expected_rent = (monthly_rent * (1 - vacancy)) * 12
    
#     income = expected_rent * (1 + rent_growth)**year

#     # Expense
#     property_management = expected_rent * management_percent
#     insurance = expected_rent * insurance_percent
#     property_tax = expected_rent * 0
#     leasing_fee = expected_rent * 0
#     hoa_fee = expected_rent * 0
#     repair_maint = expected_rent * repair_maint_percent
#     utilities = expected_rent * utilities_percent

#     expense = property_management + insurance + property_tax + \
#         leasing_fee + hoa_fee + repair_maint + utilities

#     # Capital Expenditures (Reverse)
#     capex_r = purchase_price * 0.04

#     # Net Operating Income
#     net_operating_income = income - expense
#     return net_operating_income



# def total_return(year):    
#     def net_operating_income(year, rent_growth_percentage, list_price):
#         # Income
#         rent_growth = rent_growth_percentage
#         purchase_price = list_price
        
#         monthly_rent = purchase_price * (0.8/100)
#         vacancy = 0.05
#         expected_rent = (monthly_rent * (1 - vacancy)) * 12
#         income = expected_rent * (1 + rent_growth)**year

#         # Expense
#         property_management = purchase_price * management_percent
#         insurance = (purchase_price / 1000) * 3.5
#         property_tax = purchase_price * 0
#         leasing_fee = purchase_price * 0
#         hoa_fee = purchase_price * 0
#         repair_maint = purchase_price * repair_maint_percent
#         utilities = purchase_price * utilities_percent

#         expense = property_management + insurance + property_tax + \
#             leasing_fee + hoa_fee + repair_maint + utilities

#         # Capital Expenditures (Reverse)
#         capex_r = purchase_price * 0.04

#         # Net Operating Income
#         net_operating_income = income - expense
#         return net_operating_income
    
#     def cum_net_cash_flow(year):
#         noi = net_operating_income(year, rent_growth, purchase_price)
#         total_unlevered_cash_flow = noi - capex_r
#         total_net_cash_flow = total_unlevered_cash_flow - mortgage
#         return total_net_cash_flow
    
#     def loan_balance(year_paid, loan_term):
#         remain_year = loan_term - year_paid

#         loan_balance = (monthly_payment *
#                         (1 - (1 +
#                               (loan_interest_rate / number_of_payment_per_year)) **
#                          (-(remain_year * number_of_payment_per_year)))) / (
#                              loan_interest_rate / number_of_payment_per_year)
#         return loan_balance
    
#     # Cum Net Cash Flow
#     cum_net_cash_flow = cum_net_cash_flow(year)
    
#     # Property Value
#     property_value = purchase_price * (1 + appreciation)**year
    
#     # Loan Balance
#     loan_balance = loan_balance(year_paid = year, loan_term = 30)
    
#     # Disposition Fee
#     disposition_fee = purchase_price * (3.5/100)
    
#     # Sale Proceed
#     sale_proceed = property_value - loan_balance - disposition_fee
    
#     # Total Return
#     total_return = sale_proceed + cum_net_cash_flow - initial_investment
    
#     return total_return, sale_proceed, property_value, loan_balance, disposition_fee

# def financials(year):
#     gross_yield = (expected_rent / purchase_price) * 100
#     cap_rate = (net_operating_income_year1 / purchase_price) * 100
#     cash_on_cash = (total_net_cash_flow_year1 / initial_investment) * 100
    
#     def total_return(year):    
#         def net_operating_income(year):
#             # Income
#             rent_growth = 0.03
#             monthly_rent = purchase_price * (0.8/100)
#             vacancy = 0.05
#             expected_rent = (monthly_rent * (1 - vacancy)) * 12
#             income = expected_rent * (1 + rent_growth)**year

#             # Expense
#             property_management = purchase_price * 0.08
#             insurance = (purchase_price / 1000) * 3.5
#             property_tax = purchase_price * 0
#             leasing_fee = purchase_price * 0
#             hoa_fee = purchase_price * 0
#             repair_maint = purchase_price * 0.01
#             utilities = purchase_price * 0.01

#             expense = property_management + insurance + property_tax + \
#                 leasing_fee + hoa_fee + repair_maint + utilities

#             # Capital Expenditures (Reverse)
#             capex_r = purchase_price * 0.04

#             # Net Operating Income
#             net_operating_income = income - expense
#             return net_operating_income

#         def cum_net_cash_flow(year):
#             noi = net_operating_income(year)
#             total_unlevered_cash_flow = noi - capex_r
#             total_net_cash_flow = total_unlevered_cash_flow - mortgage
#             return total_net_cash_flow

#         def loan_balance(year_paid, loan_term):
#             remain_year = loan_term - year_paid

#             loan_balance = (monthly_payment *
#                             (1 - (1 +
#                                   (loan_interest_rate / number_of_payment_per_year)) **
#                              (-(remain_year * number_of_payment_per_year)))) / (
#                                  loan_interest_rate / number_of_payment_per_year)
#             return loan_balance
    
#         # Cum Net Cash Flow
#         cum_net_cash_flow = cum_net_cash_flow(year)

#         # Property Value
#         property_value = purchase_price * (1 + appreciation)**year

#         # Loan Balance
#         loan_balance = loan_balance(year_paid = year, loan_term = 30)

#         # Disposition Fee
#         disposition_fee = purchase_price * (3.5/100)

#         # Sale Proceed
#         sale_proceed = property_value - loan_balance - disposition_fee

#         # Total Return
#         total_return = sale_proceed + cum_net_cash_flow - initial_investment

#         return total_return
        
#     total_return_year5 = total_return(year=5)
#     annualized_return_y5 = (((initial_investment / total_return_year5)**(1/5)) - 1) * 100

#     print('Gross Yield:', '{:,.2f}%'.format(gross_yield))
#     print('Cap Rate:', '{:,.2f}%'.format(cap_rate))
#     print('Cash on Cash:', '{:,.2f}%'.format(cash_on_cash))
#     print('Annualized Return in 5 Years:', '{:,.2f}%'.format(annualized_return_y5))




# # Purchase Price
# purchase_price = float(input("Enter Purchase Price:"))

# # Mortgage
# current_mortgage_rate = float(input("Enter Loan Interest Rate (%):")) / 100
# loan_interest_rate = current_mortgage_rate
# down_payment = float(input("Enter Down Payment (%):")) / 100

# loan_term = 30 
# number_of_payment_per_year = 12

# # Appreciation
# appreciation = float(input("Enter Appreciation (%):")) / 100

# # Rent Growth
# rent_growth = float(input("Enter Rent Growth (%):")) / 100

# # Expense 
# management_percent = float(input("Enter Property Management (%):")) / 100
# repair_maint_percent = float(input("Enter Repair & Maint (%):")) / 100
# utilities_percent = float(input("Enter Utilities (%):")) / 100
# capex_percent = float(input("Enter Capital Expenditures (%):")) / 100
# insurance_percent = float(input("Enter Insurance (%):")) / 100

# # Repair & Maint
# immediate_repair = 0.01 # <- default

# # Closing Cost
# closing_cost_cash = 0.015
# closing_cost_financed = 0.04


# closing_cost = 0.015


# net_operating_income_year1 = net_operating_income(year=1, rent_growth_percentage = rent_growth, list_price = purchase_price)

# # Capital Expenditures (Reverse)
# capex_r = purchase_price * capex_percent

# # Total Unlevered Cash Flow
# total_unlevered_cash_flow_year1 = net_operating_income_year1 - capex_r


# # Mortgage
# monthly_payment = monthly_payment(purchase_price, down_payment, current_mortgage_rate, number_of_payment_per_year)
# mortgage = monthly_payment * 12

# # Total Net Cash Flow 
# total_net_cash_flow_year1 = total_unlevered_cash_flow_year1 - mortgage

# # Expected Rent
# monthly_rent = purchase_price * (0.8/100)
# vacancy = 0.05
# expected_rent = (monthly_rent * (1 - vacancy)) * 12


# print('-------------')
# print('Purchase Price:', '${:,.0f}'.format(purchase_price))
# print('Loan Interest Rate:', '{:,.2f}%'.format(current_mortgage_rate* 100))
# print('Down Payment:', '{:,.2f}%'.format(down_payment* 100))
# print('Appreciation:', '{:,.2f}%'.format(appreciation* 100))

# # Initial Investment
# immediate_repair = 0.01 # <- default
# immediate_repair_cost = purchase_price * immediate_repair

# loan_fee = purchase_price * (0.75/100)

# initial_investment = (down_payment * purchase_price) + \
#     (closing_cost * purchase_price) + immediate_repair_cost + loan_fee

# print('-------------')
# # Total Return and Financials
# hist_year = float(input("Enter year(s):"))

# print('-------------')
# financials(year = hist_year)

# total_return_value = total_return(year = hist_year)[0]
# sale_proceeds = total_return(year = hist_year)[1]
# property_value = total_return(year = hist_year)[2]
# loan_balance = total_return(year = hist_year)[3]
# disposition_fee = total_return(year = hist_year)[4]

# print('-------------')
# print('Initial Investment:', '${:,.0f}'.format(initial_investment))
# print('-')
# print('Expected Rent:', '${:,.0f}'.format(expected_rent))
# print('Property Management:', '${:,.0f}'.format(property_management))
# print('Insurance:', '${:,.0f}'.format(insurance))
# print('Repair & Maint.:', '${:,.0f}'.format(repair_maint))
# print('Utilities:', '${:,.0f}'.format(utilities))

# print('---')
# print('Property Value:', '${:,.0f}'.format(property_value), 'after', round(hist_year), 'year(s)')
# print('-')
# print('Loan Balance: -', '${:,.0f}'.format(loan_balance), 'after', round(hist_year), 'year(s)')
# print('-')
# print('Disposition Fees: -', '${:,.0f}'.format(disposition_fee))
# print('--')
# print('Sale Proceeds:', '${:,.0f}'.format(sale_proceeds), 'after', round(hist_year), 'year(s)')

# noi_year = net_operating_income(year=hist_year, rent_growth_percentage = rent_growth, list_price = purchase_price)
# total_unlevered_cash_flow = noi_year - capex_r
# cum_net_cf = total_unlevered_cash_flow - mortgage

# print('---')
# print('Cum. Net Cashflow:', '${:,.2f}'.format(cum_net_cf), 'after', round(hist_year), 'year(s)')

# print('-------------')
# print('Total Return:', '${:,.0f}'.format(total_return_value), 'after', round(hist_year), 'year(s)')

# # Net Cash Flow by Year
# noi_year1 = net_operating_income(year=1, rent_growth_percentage = rent_growth, list_price = purchase_price)
# noi_year3 = net_operating_income(year=3, rent_growth_percentage = rent_growth, list_price = purchase_price)
# noi_year5 = net_operating_income(year=5, rent_growth_percentage = rent_growth, list_price = purchase_price)
# noi_year10 = net_operating_income(year=10, rent_growth_percentage = rent_growth, list_price = purchase_price)

# # Total Unlevered Cash Flow
# total_unlevered_cash_flow_y1 = noi_year1 - capex_r
# total_unlevered_cash_flow_y3 = noi_year3 - capex_r
# total_unlevered_cash_flow_y5 = noi_year5 - capex_r
# total_unlevered_cash_flow_y10 = noi_year10 - capex_r

# # Total Net Cash Flow 
# net_cf_year1 = total_unlevered_cash_flow_y1 - mortgage
# net_cf_year3 = total_unlevered_cash_flow_y3 - mortgage
# net_cf_year5 = total_unlevered_cash_flow_y5 - mortgage
# net_cf_year10 = total_unlevered_cash_flow_y10 - mortgage

# print('-------------')
# print('Net Cash Flow - Year 1:', '${:,.2f}'.format(net_cf_year1))
# print('Net Cash Flow - Year 3:', '${:,.2f}'.format(net_cf_year3))
# print('Net Cash Flow - Year 5:', '${:,.2f}'.format(net_cf_year5))
# print('Net Cash Flow - Year 10:', '${:,.2f}'.format(net_cf_year10))

# %%
 ####

# %%
matched_chicago = pd.read_csv('matched_chicago.csv')

# %%
illinois_utilities = 376.80
capex_rate = 0.04
matched_chicago['capex_r'] = matched_chicago['sold_price'] * capex_rate

# %%
# Gross Yield
matched_chicago['gross_yield'] = ((matched_chicago['listing_amount'] * 12) /
                                  matched_chicago['sold_price']) * 100

new_matched_chicago = matched_chicago.dropna(subset=['gross_yield'])

# %%
median_squarefeet_chicago = matched_chicago['square_feet'].median()

# %%
chicago_utilities_per_sf = illinois_utilities / median_squarefeet_chicago

# %%
# Utilities
new_matched_chicago['utilities'] = chicago_utilities_per_sf * new_matched_chicago['square_feet']

# %%
# Insurance 
new_matched_chicago['insurance'] = (new_matched_chicago['sold_price'] / 1000 ) * 3.5

# %%
# Repairs & Maint
repairs = 0.02
new_matched_chicago['repairs_and_maint'] = new_matched_chicago['sold_price'] * repairs

# %%
# Property Management
management = 0.03
new_matched_chicago['management'] = new_matched_chicago['sold_price'] * management

# %%
# Expense 
new_matched_chicago['expense'] = new_matched_chicago['management'] + \
    new_matched_chicago['repairs_and_maint'] + \
    new_matched_chicago['insurance'] + new_matched_chicago['utilities']

# %%
# Vaccancy at 5%
vacancy = 0.05
new_matched_chicago['income'] = (new_matched_chicago['listing_amount'] * (1 - vacancy)) * 12

# %%
# Net Operating Income 
new_matched_chicago['net_operating_income_year1'] = new_matched_chicago['income'] - new_matched_chicago['expense']

# Total Unlevered Cash Flow
new_matched_chicago['total_unlevered_cash_flow_y1'] = new_matched_chicago['net_operating_income_year1'] - new_matched_chicago['capex_r']

# %%
# Mortgage

# Mortgage Rate (replace this with API)
loan_interest_rate = 7 /100

# Down Payment (default)
down_payment = 20 /100

# Loan Term & Number of payment per year (default)
loan_term = 30 
number_of_payment_per_year = 12

# Monthly Payment Amount
def monthly_payment(purchase_price, down_payment, current_mortgage_rate, number_of_payment_per_year):
    starting_loan_amount = purchase_price - (purchase_price * down_payment)
    loan_interest_rate = current_mortgage_rate
    number_of_payment_per_year = number_of_payment_per_year
    monthly_payment = (starting_loan_amount *
                       (loan_interest_rate / number_of_payment_per_year)) / (
                           1 -
                           (1 +
                            (loan_interest_rate / number_of_payment_per_year)) **
                           (-(loan_term * number_of_payment_per_year)))
    return monthly_payment

new_matched_chicago['monthly_payment'] = monthly_payment(new_matched_chicago['sold_price'], down_payment, loan_interest_rate, number_of_payment_per_year)
new_matched_chicago['mortgage'] = new_matched_chicago['monthly_payment'] * 12

# %%
# Total Net Cash Flow
new_matched_chicago['net_cf_year1'] = new_matched_chicago['total_unlevered_cash_flow_y1'] - \
    new_matched_chicago['mortgage']

# %%
# Cash-on-Cash
new_matched_chicago['cash_on_cash'] = (new_matched_chicago['net_cf_year1'] / \
    new_matched_chicago['sold_price']) * 100

# %%
# Cap Rate
new_matched_chicago['cap_rate'] = (
    new_matched_chicago['net_operating_income_year1'] /
    new_matched_chicago['sold_price']) * 100

# %%
# Initial Investment
immediate_repair = 0.01  # <- default
closing_cost = 1.5 /100

new_matched_chicago['immediate_repair_cost'] = new_matched_chicago['sold_price'] * immediate_repair

new_matched_chicago['loan_fee'] = new_matched_chicago['sold_price'] * \
    (0.75/100)

new_matched_chicago['initial_investment'] = (down_payment * new_matched_chicago['sold_price']) + \
    (closing_cost * new_matched_chicago['sold_price']) + \
    new_matched_chicago['immediate_repair_cost'] + \
    new_matched_chicago['loan_fee']

# %%
# Total Return

# Loan Balance
remain_year = 30 - 1

new_matched_chicago['loan_balance'] = (
    new_matched_chicago['monthly_payment'] *
    (1 - (1 + (loan_interest_rate / number_of_payment_per_year))**
     (-(remain_year * number_of_payment_per_year)))) / (
         loan_interest_rate / number_of_payment_per_year)

# Disposition Fee
new_matched_chicago['disposition_fee'] = new_matched_chicago['sold_price'] * (
    3.5 / 100)

# Sale Proceed
new_matched_chicago[
    'sale_proceed'] = new_matched_chicago['sold_price'] - new_matched_chicago[
        'loan_balance'] - new_matched_chicago['disposition_fee']

# Total Return
new_matched_chicago['total_return_y1'] = new_matched_chicago[
    'sale_proceed'] + new_matched_chicago[
        'net_cf_year1'] - new_matched_chicago['initial_investment']

# %%
# Annualized Return Year 1
new_matched_chicago['annualized_return_y1'] = (
    ((new_matched_chicago['initial_investment'] / new_matched_chicago['total_return_y1'])**
     (1 / 1)) - 1) * 100

# %%
# Year > 1 

year_forward = 5
rent_growth = 0.05
appreciation = 0.05

remain_year = loan_term - year_forward

# Loan Balance Year 5
new_matched_chicago['loan_balance_y5'] = (
    new_matched_chicago['monthly_payment'] *
    (1 - (1 + (loan_interest_rate / number_of_payment_per_year))**
     (-(remain_year * number_of_payment_per_year)))) / (
         loan_interest_rate / number_of_payment_per_year)

# Income Year 5
new_matched_chicago['income_y5'] = new_matched_chicago['income'] * (
    1 + rent_growth)**year_forward

# NOI Year 5:
new_matched_chicago['noi_y5'] = new_matched_chicago[
    'income_y5'] - new_matched_chicago['expense']

# Total Unlevered Cash Flow Year 5:
new_matched_chicago['total_unlevered_cash_flow_y5'] = new_matched_chicago[
    'noi_y5'] - new_matched_chicago['capex_r']

# Paid Loan Amount Year 5:
new_matched_chicago['paid_loan_amount_y5'] = new_matched_chicago[
    'monthly_payment'] * (12 * year_forward)

# Total Net Cash Flow Year 5:
new_matched_chicago['total_net_cash_flow_y5'] = new_matched_chicago[
    'total_unlevered_cash_flow_y5'] - new_matched_chicago['paid_loan_amount_y5']

# Property Value Year 5:
new_matched_chicago['property_value_y5'] = new_matched_chicago[
    'sold_price'] * (1 + appreciation)**year_forward

# Sale Proceed Year 5:
new_matched_chicago['sale_proceed_y5'] = new_matched_chicago[
    'property_value_y5'] - new_matched_chicago[
        'loan_balance_y5'] - new_matched_chicago['disposition_fee']

# Total Return Year 5:
new_matched_chicago['total_return_y5'] = new_matched_chicago[
    'sale_proceed_y5'] + new_matched_chicago[
        'total_net_cash_flow_y5'] - new_matched_chicago['initial_investment']

# Annualized Return Year 5: 
new_matched_chicago['annualized_return_y5'] = (
    ((new_matched_chicago['initial_investment'] / new_matched_chicago['total_return_y5'])**
     (1 / year_forward)) - 1) * 100

# %%
mycols = [
    'building_name', 'address_zip', 'bedrooms', 'full_baths', 'half_baths', 'square_feet', 'year_built', 'sold_price', 'income', 'expense', 'gross_yield',
    'cap_rate', 'cash_on_cash', 'annualized_return_y1', 'annualized_return_y5'
]

# %%
df = new_matched_chicago[mycols]
# df = df.dropna(subset=['cap_rate'])
# df.replace([np.inf, -np.inf], np.nan, inplace=True)
# df.dropna(subset=["cap_rate"], how="all", inplace=True)

# Export to csv
df

# # Cap Rate < 20
# df = df.loc[df['cap_rate'] < 31]
# df2 = df.copy()
# df2 = df2.loc[df2['cap_rate'] > 9]

# # Cap Rate from 10 - 30%
# df2
# Out:
#                                    building_name  address_zip  bedrooms  \
# 0                                 2635 W Rice St      60622.0       3.0
# 1                              3200 S Wallace St      60616.0       2.0
# 3                         5223 W Washington Blvd      60644.0       3.0
# 161                               2114 W Rice St      60622.0       3.0
# 162                                816 N Wood St      60622.0       3.0
# 163                          1220 N Bosworth Ave      60642.0       2.0
# 164                              301 W North Ave      60610.0       2.0
# 167                          3116 N Clybourn Ave      60618.0       3.0
# 168                                 Urban Abodes      60618.0       2.0
# 169                             2947 N Avers Ave      60618.0       3.0
# 171                           358 W Wisconsin St      60614.0       3.0
# 172                          4563 S McDowell Ave      60609.0       1.0
# 173                         1119 W Garfield Blvd      60621.0       4.0
# 174                           1535 W Chestnut St      60642.0       2.0
# 175                            2161 N Oakley Ave      60647.0       4.0
# 177                             2302 W Touhy Ave      60645.0       3.0
# 179                           7017 S Stewart Ave      60621.0       3.0
# 180                        2318 N Sacramento Ave      60647.0       2.0
# 181                        6332 N Sacramento Ave      60659.0       5.0
# 182                          5834 N Mulligan Ave      60646.0       3.0
# 183                         1525 W Garfield Blvd      60636.0       4.0
# 185                            752 S Kedvale Ave      60624.0       3.0
# 186                             4832 W Nelson St      60641.0       2.0
# 187                        2129 N Winchester Ave      60614.0       1.0
# 188                            7741 S Yates Blvd      60649.0       3.0
# 189                          2449 N Lawndale Ave      60647.0       3.0
# 190                           3233 N Pacific Ave      60634.0       3.0
# 191                           4224 N Kimball Ave      60618.0       3.0
# 192                             1221 W Barry Ave      60657.0       1.0
# 193                             4525 S Evans Ave      60653.0       2.0
# 194                               7621 S King Dr      60619.0       4.0
# 195                          2522 N Artesian Ave      60647.0       4.0
# 196                          2416 N Artesian Ave      60647.0       2.0
# 197                         2957 N Milwaukee Ave      60618.0       1.0
# 198                            2434 N Hamlin Ave      60647.0       4.0
# 199                             2433 N Meade Ave      60639.0       2.0
# 200                          1943 N Lawndale Ave      60647.0       1.0
# 201                             3918 W North Ave      60647.0       0.0
# 202                            3516 W Belden Ave      60647.0       1.0
# 203                         1636 N Spaulding Ave      60647.0       2.0
# 204                         6427 N Nashville Ave      60631.0       2.0
# 206                           2153 N Richmond St      60647.0       3.0
# 208                          4050 W Armitage Ave      60639.0       2.0
# 209                          2055 N Keystone Ave      60639.0       3.0
# 211                                 Urban Abodes      60660.0       2.0
# 212                            924 W Gunnison St      60640.0       3.0
# 213                             4641 N Malden St      60640.0       2.0
# 214                               1644 N Troy St      60647.0       0.0
# 215                           5434 N Ashland Ave      60640.0       3.0
# 217                             5254 N Damen Ave      60625.0       1.0
# 219                           5517 W Higgins Ave      60630.0       2.0
# 223                          5011 N Lawndale Ave      60625.0       2.0
# 224                           4948 N Harding Ave      60625.0       3.0
# 226                              5028 N Clark St      60640.0       5.0
# 228                             1310 W Argyle St      60640.0       1.0
# 229                          2109 W Eastwood Ave      60625.0       3.0
# 233                           2723 W Agatite Ave      60625.0       2.0
# 234                        4711 N Monticello Ave      60625.0       2.0
# 235                                 Urban Abodes      60613.0       2.0
# 237                          3257 W Montrose Ave      60618.0       2.0
# 238                          3218 W Balmoral Ave      60625.0       2.0
# 239                          5335 W Montrose Ave      60641.0       3.0
# 240                         1127 W Patterson Ave      60613.0       3.0
# 737                               1358 W 78th St      60620.0       2.0
# 738                             7542 S Peoria St      60620.0       3.0
# 739                           7655 S Sangamon St      60620.0       2.0
# 740                           7722 S Aberdeen St      60620.0       4.0
# 741                           7704 S Aberdeen St      60620.0       3.0
# 742                          7700 S Carpenter St      60620.0       2.0
# 743                             7800 S Morgan St      60620.0       2.0
# 744                               1843 W 54th St      60609.0       2.0
# 746                             8100 S Throop St      60620.0       3.0
# 747                          8230 S Elizabeth St      60620.0       3.0
# 748                            8246 S Racine Ave      60620.0       2.0
# 749                            7956 S Normal Ave      60620.0       1.0
# 750                            7634 S Paulina St      60620.0       3.0
# 751                        7754 S Marshfield Ave      60620.0       3.0
# 752                           7800 S Ashland Ave      60620.0       4.0
# 753                             8433 S Essex Ave      60617.0       5.0
# 754                          6345 S Woodlawn Ave      60637.0       3.0
# 755                           8318 S Houston Ave      60617.0       4.0
# 756                          8454 S Muskegon Ave      60617.0       5.0
# 757                               1533 E 65th Pl      60637.0       5.0
# 758                           8449 S Brandon Ave      60617.0       2.0
# 759                               1616 W 80th St      60620.0       2.0
# 760                          7940 S Elizabeth St      60620.0       3.0
# 761                           8109 S Ashland Ave      60620.0       2.0
# 762                          8014 S Maryland Ave      60619.0       2.0
# 763                         8051 S Ingleside Ave      60619.0       1.0
# 764                          8139 S Maryland Ave      60619.0       1.0
# 765                         8155 S Ingleside Ave      60619.0       2.0
# 766                          8216 S Maryland Ave      60619.0       1.0
# ...
# 540           -209.709907                   NaN
# 542           -224.844511                   NaN
# 543           -211.630507                   NaN
# 544           -211.560244                   NaN
# 545                   NaN                   NaN
# 546           -236.598455                   NaN
# 549           -238.994934                   NaN
# 550           -210.205941                   NaN
# 551                   NaN                   NaN
# 552           -346.897688            368.186866
# 553           -252.030548                   NaN
# 554                   NaN                   NaN
# 555           -221.600182                   NaN
# 556           -215.846591                   NaN
# 557           -813.759671             23.925658
# 558           -228.837365                   NaN
# 559           -228.742876                   NaN
# 560           -207.343549                   NaN
# 563           -213.357645                   NaN
# 564                   NaN                   NaN
# 565           -251.960163                   NaN
# 566                   NaN                   NaN
# 567                   NaN                   NaN
# 568                   NaN                   NaN
# 569                   NaN                   NaN
# 570                   NaN                   NaN
# 571                   NaN                   NaN
# 572           -212.054677                   NaN
# 573                   NaN                   NaN
# 574           -222.484644                   NaN
# 575                   NaN                   NaN
# 576           -242.816115                   NaN
# 577           -283.067175                   NaN
# 578           -222.208861                   NaN
# 579           -213.822402                   NaN
# 582           -228.913471                   NaN
# 583                   NaN                   NaN
# 584                   NaN                   NaN
# 585                   NaN                   NaN
# 586           -441.676065             48.073812
# 587                   NaN                   NaN
# 588           -225.945259                   NaN
# 590                   NaN                   NaN
# 591           -240.758584                   NaN
# 593                   NaN                   NaN
# 595           -240.973837                   NaN
# 596                   NaN                   NaN
# 597                   NaN                   NaN
# 599           -100.000000           -100.000000
# 601                   NaN                   NaN
# 602                   NaN                   NaN
# 605                   NaN                   NaN
# 606           -428.285220             51.513154
# 607                   NaN                   NaN
# 608                   NaN                   NaN
# 610           -374.040790             81.393274
# 611           -465.449535             42.548935
# 612           -234.593350                   NaN
# 613                   NaN                   NaN
# 614           -242.860946                   NaN
# 615           -219.501524                   NaN
# 616                   NaN                   NaN
# 617           -227.894307                   NaN
# 618           -270.572132                   NaN
# 619                   NaN                   NaN
# 620           -304.504188                   NaN
# 621                   NaN                   NaN
# 623                   NaN                   NaN
# 624                   NaN                   NaN
# 625           -259.457845                   NaN
# 626           -223.501355                   NaN
# 627                   NaN                   NaN
# 628                   NaN                   NaN
# 629                   NaN                   NaN
# 630             73.768016             -4.504589
# 631                   NaN                   NaN
# 632                   NaN                   NaN
# 634                   NaN                   NaN
# 635                   NaN                   NaN
# 636            -70.620264            -27.219786
# 637           -511.312639             37.465504
# 638           -279.336486                   NaN
# 639                   NaN                   NaN
# 640           -100.000000           -100.000000
# 641                   NaN                   NaN
# 642                   NaN                   NaN
# 643           -100.000000           -100.000000
# 644           -329.906171                   NaN
# 646           -261.121588                   NaN
# 647           -231.783092                   NaN
# 648           -230.320219                   NaN
# 649           -231.975501                   NaN
# 650                   NaN                   NaN
# 651           -226.971135                   NaN
# 653                   NaN                   NaN
# 655                   NaN                   NaN
# 657              9.967494             -9.942392
# 658           -230.807162                   NaN
# 659            -57.202611            -22.145863
# 660           -209.340656                   NaN
# 661           -224.925167                   NaN
# 662           -212.799655                   NaN
# 663           -239.435698                   NaN
# 664                   NaN                   NaN
# 666           -221.306946                   NaN
# 667           -100.000000           -100.000000
# 668           -259.344983                   NaN
# 669           -211.875715                   NaN
# 670          -1338.199842             19.227077
# 672           -210.846721                   NaN
# 673           -228.481594                   NaN
# 674                   NaN                   NaN
# 675           -208.210231                   NaN
# 676           -207.966158                   NaN
# 678           -208.082795                   NaN
# 679           -212.482670                   NaN
# 680           -208.586816                   NaN
# 681                   NaN                   NaN
# 682           -260.318659                   NaN
# 683           -219.190382                   NaN
# 684                   NaN                   NaN
# 685           -383.483732             73.394531
# 686           -208.713904                   NaN
# 687                   NaN                   NaN
# 688           -222.279681                   NaN
# 689                   NaN                   NaN
# 690           -333.574904                   NaN
# 691                   NaN                   NaN
# 692           -260.196887                   NaN
# 693           -282.649264                   NaN
# 694            -32.841492            -16.399809
# 695                   NaN                   NaN
# 696           -248.634196                   NaN
# 697                   NaN                   NaN
# 698           -435.671431             48.351302
# 699                   NaN                   NaN
# 700           -225.371772                   NaN
# 701           -221.736403                   NaN
# 703                   NaN                   NaN
# 704           -248.186027                   NaN
# 705             16.700903             -9.248531
# 706                   NaN                   NaN
# 707           -100.000000           -100.000000
# 709                   NaN                   NaN
# 710                   NaN                   NaN
# 711           -255.181172                   NaN
# 712                   NaN                   NaN
# 713                   NaN                   NaN
# 714                   NaN                   NaN
# 715           -211.021774                   NaN
# 716           -234.615170                   NaN
# 717                   NaN                   NaN
# 718            166.275378             -0.029245
# 719                   NaN                   NaN
# 720                   NaN                   NaN
# 721           -284.043590                   NaN
# 722           -228.404391                   NaN
# 723                   NaN                   NaN
# 724           -225.192962                   NaN
# 726           -210.786428                   NaN
# 727           -228.334715                   NaN
# 728                   NaN                   NaN
# 729           -268.216168                   NaN
# 730            -61.665940            -23.702097
# 731            -66.277695            -25.354798
# 732           -268.440702                   NaN
# 733           -270.985351                   NaN
# 734            162.282062             -0.227007
# 735           -214.968735                   NaN
# 736           -217.589723                   NaN
# 737           -220.655638                   NaN
# 738           -255.489894                   NaN
# 739           -235.671306                   NaN
# 740                   NaN                   NaN
# 741           -229.387660                   NaN
# 742            678.293068              7.876878
# 743           -223.218922                   NaN
# 744                   NaN                   NaN
# 746           -241.276083                   NaN
# 747           -242.631572                   NaN
# 748                   NaN                   NaN
# 749           -219.172979                   NaN
# 750           -242.603172                   NaN
# 751           -233.446057                   NaN
# 752           -293.876265                   NaN
# 753           -220.716173                   NaN
# 754                   NaN                   NaN
# 755            308.917467              3.894067
# 756           1098.062818              9.736235
# 757                   NaN                   NaN
# 758           -234.337775                   NaN
# 759           -305.677883                   NaN
# 760                   NaN                   NaN
# 761           -100.000000           -100.000000
# 762          10828.632472             13.404261
# 763           -212.008754                   NaN
# 764                   NaN                   NaN
# 765           -256.179538                   NaN
# 766           -245.253794                   NaN
# 767                   NaN                   NaN
# 768                   NaN                   NaN
# 770           -218.958776                   NaN
# 771           -218.694752                   NaN
# 772                   NaN                   NaN
# 773                   NaN                   NaN
# 774           -217.206818                   NaN
# 775           -211.651059                   NaN
# 776           -295.289925                   NaN
# 777          -1936.835618             17.206441
# 778                   NaN                   NaN
# 779           -221.739431                   NaN
# 780            184.108636              0.448152
# 781           -357.689549            112.253911
# 782                   NaN                   NaN
# 783                   NaN                   NaN
# 784            -79.273170            -31.584669
# 785           -479.717483             40.483454
# 786           -897.663640             23.082582
# 787            -29.198860            -15.608913
# 788            -33.055636            -16.390475
# 789                   NaN                   NaN
# 790            -43.731867            -18.596619
# 791           -221.546998                   NaN
# 792           -343.358229                   NaN
# 793                   NaN                   NaN
# 794                   NaN                   NaN
# 795            264.640452              2.754102
# 796           -459.336627             43.483499
# 797           -218.814192                   NaN
# 798           -213.901354                   NaN
# 799           -215.275506                   NaN
# 800           -250.451003                   NaN
# 801                   NaN                   NaN
# 802           -364.458144             95.315398
# 804           -464.168036             42.821319
# 805           -231.287817                   NaN
# 806           -100.000000           -100.000000
# 807            -71.321839            -27.915463
# 809              8.761680            -10.421247
# 811           -263.784009                   NaN
# 812           -283.725681                   NaN
# 813           -261.520726                   NaN
# 814           -231.290477                   NaN
# 815                   NaN                   NaN
# 816           -229.445622                   NaN
# 817           -239.776189                   NaN
# 818                   NaN                   NaN
# 819           -364.495006             96.464350
# 820           -225.122894                   NaN
# 821           -279.308573                   NaN
# 822             12.951276             -9.636902
# 823           -251.393080                   NaN
# 824            984.753590              9.417018
# 825           -224.770208                   NaN
# 826            -58.722250            -22.625818
# 827           -236.286949                   NaN
# 828                   NaN                   NaN
# 830           -264.711153                   NaN
# 831           -230.586487                   NaN
# 832           -294.459399                   NaN
# 833           -344.056641                   NaN
# 834           -238.490547                   NaN
# 835           -264.512414                   NaN
# 836           -303.654540                   NaN
# 837           -874.116111             23.090004
# 838           -258.256148                   NaN
# 839          -1140.889314             20.189019
# 840           -227.568858                   NaN
# 841           -243.568999                   NaN
# 842                   NaN                   NaN
# 843           -225.184842                   NaN
# 844                   NaN                   NaN
# 845           -236.016778                   NaN
# 846           -251.204728                   NaN
# 847           -228.641279                   NaN
# 848           -238.629715                   NaN
# 850                   NaN                   NaN
# 851                   NaN                   NaN
# 853                   NaN                   NaN
# 860           -227.633283                   NaN
# 862                   NaN                   NaN
# 868                   NaN                   NaN
# 869                   NaN                   NaN
# 870           -245.458644                   NaN
# 871                   NaN                   NaN
# 872           -218.938801                   NaN
# 873           -218.941964                   NaN
# 874                   NaN                   NaN
# 875           -211.560084                   NaN
# 876           -237.361417                   NaN
# 878           -230.859911                   NaN
# 879           -225.705124                   NaN
# 880           -220.281484                   NaN
# 881                   NaN                   NaN
# 882           -323.198084                   NaN
# 883           -240.600384                   NaN
# 884           -242.186747                   NaN
# 885           -263.939712                   NaN
# 886           -234.705122                   NaN
# 887           -238.152274                   NaN
# 888           -231.438432                   NaN
# 890                   NaN                   NaN
# 891           -242.507104                   NaN
# 892                   NaN                   NaN
# 893                   NaN                   NaN
# 894                   NaN                   NaN
# 895                   NaN                   NaN
# 896                   NaN                   NaN
# 897                   NaN                   NaN
# 898           -229.701999                   NaN
# 900           -231.116823                   NaN
# 901                   NaN                   NaN
# 902           -230.116846                   NaN
# 903           -264.029772                   NaN
# 906                   NaN                   NaN
# 907           -220.296801                   NaN
# 908                   NaN                   NaN
# 909           -223.393728                   NaN
# 910                   NaN                   NaN
# 911                   NaN                   NaN

# %%
def monthly_payment(purchase_price, down_payment, interest_rate, loan_term, number_of_payment_per_year):
    starting_loan_amount = purchase_price - (purchase_price * down_payment)

    monthly_payment = (starting_loan_amount *
                       (interest_rate / number_of_payment_per_year)) / (
                           1 -
                           (1 +
                            (interest_rate / number_of_payment_per_year)) **
                           (-(loan_term * number_of_payment_per_year)))
    
    return monthly_payment

property_value = 1000000
down_payment_percentage = 20/100
down_payment_amount = property_value * down_payment_percentage
loan_amount = property_value - down_payment_amount


interest_rate = 4.5 /100
loan_term = 30
number_of_payment_per_year = 12

property_tax_percentage = 1.75/100

property_tax = property_value * property_tax_percentage
homeowner_insurance = 1000
hoa_per_month = 200
pmi_per_month = 200
extra_payment = 200


monthly_payment1 = monthly_payment(property_value, down_payment_percentage, interest_rate, loan_term, number_of_payment_per_year)
interest_paid = (loan_amount * interest_rate) / 12
princial_paid = monthly_payment1 - interest_paid


monthly_payment2 =  monthly_payment1 + property_tax / 12 + homeowner_insurance / 12 + hoa_per_month + pmi_per_month + extra_payment

print("Monthly Payment:", monthly_payment1)
print("Interest Payment:", interest_paid)
print("Principal:", princial_paid)

print("Monthly Payment with Fees:", monthly_payment2)
# Out:
# Monthly Payment: 4053.4824786070863
# Interest Payment: 3000.0
# Principal: 1053.4824786070863
# Monthly Payment with Fees: 6195.149145273753
